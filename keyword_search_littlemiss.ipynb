# %%
# !pip install textblob
import textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tweepy as tw
from textblob import TextBlob

# %%
consumer_key= 'insert'
consumer_secret= 'insert'
access_token= 'insert'
access_token_secret= 'insert'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
public_tweets = api.search('Little miss')

# %%
for tweet in public_tweets:
  print(tweet.text)
  analysis = TextBlob(tweet.text)
  print(analysis.sentiment)
# Out:
# RT @diorkenn: little miss wake up in the middle of the night and can’t go back to sleep
# Sentiment(polarity=-0.0625, subjectivity=0.16666666666666666)
# RT @lovemyseIf_: little miss army edition: a thread https://t.co/KiChoPC38i
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# RT @littlem1ssss: little miss “it is what it is”
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# RT @LittleMissNotes: little miss stays up all night scrolling on tiktok
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# RT @LittleMissNotes: little miss stays up all night scrolling on tiktok
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# RT @heavenbrat: little miss stomach issues fr
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# RT @littlem1ssss: little miss stays up for no reason
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# RT @heavenbrat: little miss stomach issues fr
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# RT @_FloMilli: little miss on her FLY shit ♠️ https://t.co/HsbYnbywAR
# ...

# %%
#Try to extract 100 tweets from my little miss
posts = api.search("little miss", count = 100, lang ="en", tweet_mode="extended")

#Print the last 10 tweets from the account
print("Show the 100 recent tweets: \n")
for tweet in posts[0:100]:
  print(tweet.full_text + '\n')
# Out:
# Show the 100 recent tweets:
#
# RT @LittleMissNotes: little miss doesn’t know how to express her feelings
#
# Little Miss NTUA 😃 https://t.co/sNV5sg4uDq
#
# RT @tinaqueen_15: Little Miss I’m Full after 3 bites
#
# RT @OrianaNichelle: little miss “look how pretty the moon is”
#
# RT @twinnstaylit: little miss not ran through, wya?
#
# RT @LittleMissNotes: little miss doesn’t know how to express her feelings
#
# RT @Killa_Kayee16: little miss get money.
#
# Partaking in the little miss trend @thatbitchlemon #littlemiss #itslikebffnecklace https://t.co/Lwqd0XcJA0
#
# Every time I see these "Little Miss..." memes.
#
# Anybody else?
#
# https://t.co/0NgJ7iaQa1
#
# RT @LittleMissNotes: little miss doesn’t know how to express her feelings
#
# RT @littlem1ssss: little miss “it is what it is”
#
# Is the “Little Miss” trend supposed to be funny or is it just saying what quirky thing you do? Serious question
#
# Little Miss jewelry designer 💎 https://t.co/EVzLgMzMve
#
# ...
